# %% [markdown]
# ## Q1.
#
# Add methods `__iter__` to your project Time Series class to iterate over values, a method `itertimes` to iterate over times, a method `itervalues` to iterate over values, and a method `iteritems` to iterate over time-value pairs. (This is a similar interface to python dictionaries). To test these, check both the types of the results and the answers you expect.

# %%
#your code here

# Ignore the "your code here" -- this part should go in your team repo 

# The remainder of Q2 and Q3 are individual and should go in your individual repo
    # (Rahul will have code for us on these parts next week)

# %% [markdown]
# ## Q2.
#
# An online mean and standard deviation algorithm.
#
# Below is a function to generate a potentially infinite stream of 1-D data.

# %%
from random import normalvariate, random
from itertools import count
def make_data(m, stop=None):
    # count() is buit in function that will count from 0, 1, 2.... 
    for _ in count():
        # check if stop was passed in by caller 
        if stop and _ > stop:
            break
        yield 1.0e09 + normalvariate(0, m*random() )

# %% [markdown]
# Here is an implementation of an online mean algorithm..see http://www.johndcook.com/blog/standard_deviation/ and the link to http://www.johndcook.com/blog/2008/09/26/comparing-three-methods-of-computing-standard-deviation/ in-between. (Convince yourselves of the formulas...)

# %%
# want to be able to calculate mean as data coming in for data in so far, so don't have to go back to calculate 
    # whole thing each time
def online_mean(iterator):
    n = 0
    mu = 0
    for value in iterator:
        n += 1
        delta = value - mu
        mu = mu + delta/n
        yield mu

# %% [markdown]
# We use out generator functions to implement iterators:

# %%
# create 10 numbers normally distributed centered around 0 with standard deviation of 5
g = make_data(5, 10)
list(g)
# Out:
# [1000000004.0873431,
#  1000000000.0362349,
#  999999998.8757737,
#  999999998.8342792,
#  999999999.5923191,
#  999999993.4534973,
#  1000000001.5568576,
#  999999998.4348311,
#  999999994.2520593,
#  1000000000.0587723,
#  999999999.9784975]

# %%
g = online_mean(make_data(5, 100))
print(type(g))
list(g)
# Out:
# <class 'generator'>
# [999999996.1819191,
#  999999997.5161544,
#  999999999.4237866,
#  999999998.4165289,
#  999999998.7766865,
#  999999998.9320949,
#  999999998.3057137,
#  999999998.5775262,
#  999999998.6950045,
#  999999998.8133467,
#  999999999.0003135,
#  999999998.9305927,
#  999999998.9396323,
#  999999999.0702626,
#  999999999.544868,
#  999999999.6549721,
#  999999999.9420701,
#  1000000000.0088178,
#  1000000000.2216057,
#  1000000000.362086,
#  1000000000.3412274,
#  1000000000.3128247,
#  1000000000.3562423,
#  1000000000.3264697,
#  1000000000.2560791,
#  1000000000.4880837,
#  1000000000.446695,
#  1000000000.4068334,
#  1000000000.448662,
#  1000000000.4129564,
#  1000000000.4177471,
#  1000000000.3991857,
#  1000000000.3596725,
#  1000000000.2365427,
#  1000000000.1385064,
#  1000000000.0486046,
#  1000000000.0161043,
#  1000000000.004261,
#  999999999.9772043,
#  1000000000.0189756,
#  1000000000.0584393,
#  1000000000.0176476,
#  1000000000.0527754,
# ...

# %% [markdown]
# ### 2.1
#
# Implement the standard deviation algorithm as a generator function as
#
# ```python
# def online_mean_dev(iterator):
#     BLA BLA
#     if n > 1:
#         stddev = math.sqrt(dev_accum/(n-1))
#         yield (n, value, mu, stddev)
# ```

# %%
# your code here
import math

def online_mean_dev(iterator):
    """
    http://www.johndcook.com/blog/standard_deviation/
    Mk = Mk-1+ (xk – Mk-1)/k
    Sk = Sk-1 + (xk – Mk-1)*(xk – Mk)
    For 2 ≤ k ≤ n, the kth estimate of the variance is s2 = Sk/(k – 1).
    """
    n = 0
    mu = 0
    dev_accum = 0
    
    for value in iterator:
        n += 1
        delta = value - mu
        mu2 = mu + delta/n
        
        dev_accum += (value - mu2)*(value-mu)
        
        mu = mu2
    
        if n > 1: 
            stddev = math.sqrt(dev_accum/(n-1))
            yield (n, value, mu, stddev)

# %% [markdown]
# Here we make 100000 element data, and run this iterator on it (imagine running this on a time-series being slowly read from disk

# %%
data_with_stats = online_mean_dev(make_data(5, 100000))

# %%
list(data_with_stats)
# Out:
# [(2, 1000000000.0599986, 1000000000.880129, 1.159839461346081),
#  (3, 1000000001.58555, 1000000001.1152693, 0.9156891958797079),
#  (4, 1000000001.6844105, 1000000001.2575545, 0.7999822241532547),
#  (5, 1000000001.3361044, 1000000001.2732645, 0.6936949509069886),
#  (6, 1000000001.0410151, 1000000001.2345563, 0.6276624181892444),
#  (7, 999999999.8123392, 1000000001.0313824, 0.7856573421986139),
#  (8, 1000000000.142926, 1000000000.9203254, 0.7923049824425927),
#  (9, 999999996.8812226, 1000000000.4715362, 1.5368749053855097),
#  (10, 1000000000.6614087, 1000000000.4905235, 1.4502230556453408),
#  (11, 1000000000.926148, 1000000000.5301257, 1.3820578593012616),
#  (12, 1000000004.1563615, 1000000000.8323121, 1.6829256391839187),
#  (13, 1000000003.1176654, 1000000001.0081085, 1.7314663495865048),
#  (14, 999999999.3872931, 1000000000.892336, 1.7190137010813882),
#  (15, 1000000004.664073, 1000000001.1437851, 1.921545235730392),
# ...

# %% [markdown]
# ## Q3.
#
# Let's do Anomaly detection. Write a routine `is_ok`:
#
# ```python
# def is_ok(level, t)
# ```
#
# which takes a tuple like the one yielded by your code above and returns True if the value is inbetween `level`-$\sigma$ of the mean.

# %%
#your code here
# TODO check if this is right? why is it level - sigma? 
def is_ok(level, t): 
     return (t[1] < t[2] + (level - t[3])) and (t[1] > t[2] - (level - t[3]))
     return (t[1] < t[2] + (level*t[3])) and (t[1] > t[2] - (level*t[3]))
    #     return (t[1] < t[2] + t[3]) & (t[1] > t[2] - t[3])

# %% [markdown]
# We use this function to create a predicate passed through to `itertools.filterfalse` which is then used to obtain an iterator on the anomalies.

# %%
from itertools import filterfalse
pred = lambda t: is_ok(5, t)
anomalies = filterfalse(pred, data_with_stats)

# %% [markdown]
# We materialize the anomalies...

# %%
list(anomalies)#materialize
# Out:
# []

# %% [markdown]
# ## To think of, but not hand in
#
# What kinds of anomalies will this algorithm pick up? What kinds would a shorter "window" of anomaly detection, like 100 points around the time in question pick? How might you create an algorithm which does window based averaging? (hint: the window size is small compared to the time series size).
#
# Finally think a bit of how you might implement all of this in a production environment..remember that data streaming in might get backed up when you handle an anomaly.
#
# (Some inspiration might accrue if you look at the docs for `collections.deque`).
